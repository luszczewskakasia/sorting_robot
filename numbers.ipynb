# %% [markdown]
# <a href="https://colab.research.google.com/github/luszczewskakasia/sorting_robot/blob/main/numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import math
import os
import copy
import random 

numbers = cv2.imread("numbers.png",cv2.IMREAD_COLOR)
plt.imshow(numbers)
plt.show()

gray = cv2.imread("numbers.png", cv2.IMREAD_GRAYSCALE)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)
thresh = cv2.adaptiveThreshold(blurred,255,1,1,11,2)

contours,hierarchy = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

img =  np.zeros((600, 1600))
res = []

for cnt in contours:
    if cv2.contourArea(cnt)>2000:
        [x,y,w,h] = cv2.boundingRect(cnt)
        
        if  h>150:
            cv2.rectangle(numbers,(x,y),(x+w,y+h),(0,0,255),2)
            number = thresh[y:y+h,x:x+w]

            plt.imshow(numbers)
            plt.show()
            key = cv2.waitKey(0)
